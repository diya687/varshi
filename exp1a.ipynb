# %% [markdown]
# <a href="https://colab.research.google.com/github/diya687/varshi/blob/main/exp1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
Series_A=pd.Series([10,20,30,40,50])
Series_B=pd.Series([40,50,60,70,80,])
union=pd.Series(np.union1d(Series_A.values,Series_B.values))
intersect=pd.Series(np.intersect1d(Series_A.values,Series_B.values))
notcommonseries=union[-union.isin(intersect)]
print(notcommonseries)
# Out:
# 0    10
# 1    20
# 2    30
# 5    60
# 6    70
# 7    80
# dtype: int64
